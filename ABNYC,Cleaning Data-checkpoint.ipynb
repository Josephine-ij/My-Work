# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

# %%
AB_NYC_2019 = pd.read_excel(r'C:\Users\o\Documents\AB_NYC_2019.xlsx')

# %%
AB_NYC_2019
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
print(AB_NYC_2019.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48869 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48873 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
for column in AB_NYC_2019.columns:
    if AB_NYC_2019[column].isnull().sum() != 0:
        print(f"{column}: {AB_NYC_2019[column].isnull().sum()} missing values, dtype: {AB_NYC_2019[column].dtypes}")
# Out:
# name: 26 missing values, dtype: object
# host_name: 22 missing values, dtype: object
# last_review: 10052 missing values, dtype: datetime64[ns]
# reviews_per_month: 10052 missing values, dtype: float64

# %%
AB_NYC_2019["last_review"] = pd.to_datetime(AB_NYC_2019.last_review)
AB_NYC_2019["reviews_per_month"].fillna(AB_NYC_2019["reviews_per_month"].mean(), inplace=True)
AB_NYC_2019["last_review"].ffill(inplace=True)
AB_NYC_2019.fillna(AB_NYC_2019.mode().iloc[0], inplace=True)

# %%
print("Number of duplicate records:", AB_NYC_2019.duplicated().sum())
# Out:
# Number of duplicate records: 0

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x=AB_NYC_2019['price'])
# Out:
# <Axes: xlabel='price'>

# %%
scaler = StandardScaler()
label_encoder = LabelEncoder()

# %%
cols_to_scale = ['host_id', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 
                 'calculated_host_listings_count', 'availability_365']
AB_NYC_2019[cols_to_scale] = scaler.fit_transform(AB_NYC_2019[cols_to_scale])
AB_NYC_2019['neighbourhood'] = label_encoder.fit_transform(AB_NYC_2019['neighbourhood'])

# %%
X = AB_NYC_2019.drop(['name', 'price', 'last_review'], axis=1)
y = AB_NYC_2019['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
non_numeric_cols_X = X_train.select_dtypes(exclude=[np.number]).columns
print("Columns with non-numeric values in X_train:", non_numeric_cols_X)
# Out:
# Columns with non-numeric values in X_train: Index(['host_name', 'neighbourhood_group', 'room_type'], dtype='object')

# %%
non_numeric_vals_y = y_train[~y_train.apply(lambda x: isinstance(x, (int, float)))].unique()
print("Non-numeric values in y_train:", non_numeric_vals_y)
# Out:
# Non-numeric values in y_train: []

# %%
X_train_cleaned = X_train.drop(columns=['host_name'])

# %%
y_train_cleaned = y_train[~(y_train == 'Ruishu')]

# %%
y_train_cleaned = pd.to_numeric(y_train_cleaned)

# %%
X_train_encoded = pd.get_dummies(X_train_cleaned)

# %%
lin_reg.fit(X_train_encoded, y_train_cleaned)
# Out:
# LinearRegression()

# %%
missing_columns = set(X_train_encoded.columns) - set(X_test_encoded.columns)
for column in missing_columns:
    X_test_encoded[column] = 0

# %%
X_test_encoded = X_test_encoded[X_train_encoded.columns]

# %%
y_pred = lin_reg.predict(X_test_encoded)

# %%
def print_evaluate(true, predicted):  
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("R-squared:", metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 73.81232222474571
# Mean Squared Error: 47427.988401673014
# R-squared: 0.10970158137539932

# %%
print("Evaluation on Test Set:")
print_evaluate(y_test, y_pred)
print("Average price in the dataset:", AB_NYC_2019['price'].mean())
# Out:
# Evaluation on Test Set:
# Average price in the dataset: 152.7206871868289

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(AB_NYC_2019.isnull(), cmap='viridis', cbar=False)
plt.title('Missing Data Patterns')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='room_type', y='price', data=AB_NYC_2019)
plt.title('Distribution of Prices by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()
